# %%
from matplotlib import dates
import matplotlib.pyplot as plt
import numpy as np
import pandas as np
# !pip install yfinance
import yfinance as yf

# %%
raw = yf.download('SPY AAPL', start='2010-01-01', end='2019-12-31')
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
raw
# Out:
# Price       Adj Close                  Close                   High  \
# Ticker           AAPL         SPY       AAPL         SPY       AAPL
# Date
# 2010-01-04   6.470742   87.129944   7.643214  113.330002   7.660714
# 2010-01-05   6.481929   87.360611   7.656429  113.629997   7.699643
# 2010-01-06   6.378826   87.422081   7.534643  113.709999   7.686786
# 2010-01-07   6.367031   87.791145   7.520714  114.190002   7.571429
# 2010-01-08   6.409362   88.083313   7.570714  114.570000   7.571429
# ...               ...         ...        ...         ...        ...
# 2019-12-23  69.082329  301.631073  71.000000  321.220001  71.062500
# 2019-12-24  69.147995  301.640381  71.067497  321.230011  71.222504
# 2019-12-26  70.519920  303.246124  72.477501  322.940002  72.495003
# 2019-12-27  70.493156  303.170990  72.449997  322.859985  73.492500
# 2019-12-30  70.911545  301.499603  72.879997  321.079987  73.172501
#
# Price                         Low                   Open              \
# ...

# %%
raw.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
if raw.empty:
    print("DataFrame is empty")
else:
    # Your code processing the data here
    print(raw.head())
# Out:
# Price      Adj Close                Close                  High              \
# Ticker          AAPL        SPY      AAPL         SPY      AAPL         SPY
# Date
# 2010-01-04  6.470742  87.129944  7.643214  113.330002  7.660714  113.389999
# 2010-01-05  6.481929  87.360611  7.656429  113.629997  7.699643  113.680000
# 2010-01-06  6.378826  87.422081  7.534643  113.709999  7.686786  113.989998
# 2010-01-07  6.367031  87.791145  7.520714  114.190002  7.571429  114.330002
# 2010-01-08  6.409362  88.083313  7.570714  114.570000  7.571429  114.620003
#
# Price            Low                  Open                 Volume
# Ticker          AAPL         SPY      AAPL         SPY       AAPL        SPY
# Date
# 2010-01-04  7.585000  111.510002  7.622500  112.370003  493729600  118944600
# 2010-01-05  7.616071  112.849998  7.664286  113.260002  601904800  111579900
# 2010-01-06  7.526786  113.430000  7.656429  113.519997  552160000  116074400
# ...

# %%
import yfinance as yf

# Download historical stock data
data = yf.download('AAPL', start='2022-01-01', end='2022-01-31')

# Access the 'Close' column
close_prices = data['Close']

# Your code using close_prices here
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# line plot

#line plots

# %%
def fix_cols(df):
    # Your code to fix columns here
    return df

(raw
.iloc[:, :-2:2]
.pipe(fix_cols)
)
# Out:
# Price       Adj Close      Close       High        Low       Open
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2010-01-04   6.470742   7.643214   7.660714   7.585000   7.622500
# 2010-01-05   6.481929   7.656429   7.699643   7.616071   7.664286
# 2010-01-06   6.378826   7.534643   7.686786   7.526786   7.656429
# 2010-01-07   6.367031   7.520714   7.571429   7.466071   7.562500
# 2010-01-08   6.409362   7.570714   7.571429   7.466429   7.510714
# ...               ...        ...        ...        ...        ...
# 2019-12-23  69.082329  71.000000  71.062500  70.092499  70.132500
# 2019-12-24  69.147995  71.067497  71.222504  70.730003  71.172501
# 2019-12-26  70.519920  72.477501  72.495003  71.175003  71.205002
# 2019-12-27  70.493156  72.449997  73.492500  72.029999  72.779999
# 2019-12-30  70.911545  72.879997  73.172501  71.305000  72.364998
#
# [2515 rows x 5 columns]

# %%
(raw
.iloc[:, :-2:2]
.pipe(fix_cols)
.plot()
)
# Out:
# <Axes: xlabel='Date'>

# %%
(raw
.iloc[:, ::2]
.pipe(fix_cols)
.Close
#.plot()
)
# Out:
# Ticker           AAPL
# Date
# 2010-01-04   7.643214
# 2010-01-05   7.656429
# 2010-01-06   7.534643
# 2010-01-07   7.520714
# 2010-01-08   7.570714
# ...               ...
# 2019-12-23  71.000000
# 2019-12-24  71.067497
# 2019-12-26  72.477501
# 2019-12-27  72.449997
# 2019-12-30  72.879997
#
# [2515 rows x 1 columns]

# %%
(raw
.iloc[:, ::2]
.pipe(fix_cols)
.Volume
.plot(figsize=(10,2))
)
# Out:
# <Axes: xlabel='Date'>

# %%
# Resampling

# %%
(raw
 .iloc[:, ::2]
 .pipe(fix_cols)
 .resample('M')
 .Close
)

# %%
(raw
 .iloc[:, ::2]
 .pipe(fix_cols)
 .resample('2M')
 .Close
 .mean()
)
# Out:
# Ticker           AAPL
# Date
# 2010-01-31   7.418402
# 2010-03-31   7.581267
# 2010-05-31   8.975044
# 2010-07-31   9.218563
# 2010-09-30   9.368754
# ...               ...
# 2019-05-31  48.946861
# 2019-07-31  49.846072
# 2019-09-30  52.791488
# 2019-11-30  61.988372
# 2020-01-31  68.917374
#
# [61 rows x 1 columns]

# %%
(raw
 .iloc[:, ::2]
 .pipe(fix_cols)
 .resample('M')
 .Close
 .mean()
 .plot()
)
# Out:
# <Axes: xlabel='Date'>
